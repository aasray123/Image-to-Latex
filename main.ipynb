# %%
from datasets import load_dataset

ds = load_dataset("OleehyO/latex-formulas", "cleaned_formulas")

# %%
import matplotlib.pyplot as plt 
from PIL import Image

# Access the 'train' split of the dataset
train_ds = ds['train']

# 1. See a single specific example (the first one)
first_example = train_ds[0]
image_to_display = first_example['image']
print(first_example)
# 4. Display the image
print("Displaying the image from the first example:")
plt.imshow(image_to_display)
plt.axis('off')  # Optional: to hide the x and y axes
plt.show()
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=323x44 at 0x23C74756440>, 'latex_formula': '\\begin{align*}-\\div (y^{1-2m}\\nabla w)=0\\mbox{in}\\mathbb R^n\\times\\mathbb R_+;w\\big|_{y=0}=|u|\\end{align*}'}
# Displaying the image from the first example:
